# %%
import sys
sys.path.append('..')
from utils import setup_colab, load_corpus, get_ngrams, most_common_ngrams, create_transition_matrix
from utils import compare_two_corpora_bigrams, jaccard, jaccard_matrix

setup_colab()  # replaces the "ignore this code" cell
# Out:
# Data directory found — running locally, no clone needed.

# %%
most_common_ngrams('../data/happy_birthday.krn', n=3)
# Out:
# [(('D4', 'D4', 'E4'), 2),
#  (('D4', 'E4', 'D4'), 2),
#  (('E4', 'D4', 'G4'), 1),
#  (('D4', 'G4', 'F#4'), 1),
#  (('G4', 'F#4', 'D4'), 1),
#  (('F#4', 'D4', 'D4'), 1),
#  (('E4', 'D4', 'A4'), 1),
#  (('D4', 'A4', 'G4'), 1),
#  (('A4', 'G4', 'D4'), 1),
#  (('G4', 'D4', 'D4'), 1),
#  (('D4', 'D4', 'D5'), 1),
#  (('D4', 'D5', 'B4'), 1),
#  (('D5', 'B4', 'G4'), 1),
#  (('B4', 'G4', 'F#4'), 1),
#  (('G4', 'F#4', 'E4'), 1),
#  (('F#4', 'E4', 'C5'), 1),
#  (('E4', 'C5', 'C5'), 1),
#  (('C5', 'C5', 'B4'), 1),
#  (('C5', 'B4', 'G4'), 1),
#  (('B4', 'G4', 'A4'), 1),
#  (('G4', 'A4', 'G4'), 1)]
