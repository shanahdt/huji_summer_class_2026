# %% [markdown]
# # Day 8: Presentations and Synthesis
# **Date:** Tuesday 30 June 2026
#
# No new code today. This notebook holds the synthesis questions and final log prompt.

# %% [markdown]
# ## Session schedule
#
# | Time | Activity |
# |------|----------|
# | 0:00–1:30 | Presentations (10–12 min each) |
# | 1:30–1:45 | Break |
# | 1:45–2:30 | Synthesis discussion |
# | 2:30–3:00 | Final log entry and close |

# %% [markdown]
# ---
# ## Discussion Question 1: Return to Day 1
#
# On Day 1 we asked: *what does it mean to represent music as data?*
#
# After eight sessions:
# - Has your answer changed?
# - What did you learn that you could not have learned by listening?
# - What did listening teach you that the corpus could not?

# %% [markdown]
# ---
# ## Discussion Question 2: The Encoding Chain
#
# Beregovski heard musicians → transcribed → typeset → Malin/Shanahan encoded kern → you loaded Python.
#
# At which step was the most significant information lost?
# Does it matter which step, or does each loss compound the others?

# %% [markdown]
# ---
# ## Discussion Question 3: Methods and Their Theories
#
# | Method | Implicit theory |
# |--------|-----------------|
# | Pitch histogram | Frequency = importance |
# | KS key-finding | Western probe-tone salience defines tonality |
# | Edit distance | Melodies are strings; all edits cost equally |
# | N-gram Jaccard | Local patterns are what similarity is |
# | Contour | Shape matters more than interval size |
# | Hierarchical clustering | Feature-space proximity = musical relationship |
#
# Which theory was most wrong for this repertoire? Most right?
# What would a method look like that was *designed for klezmer* rather than adapted from elsewhere?

# %% [markdown]
# ---
# ## Discussion Question 4: The Missing Corpus
#
# Why does a large, computationally ready corpus of Israeli folk music not exist?
#
# - What collection decisions would have to be made?
# - Who would be qualified to make them?
# - Is the absence a problem to be solved, or a condition to be understood?

# %% [markdown]
# ---
# ## Discussion Question 5: Spotify Was librosa at Scale
#
# Do you believe this claim? What does it imply for:
# - How we understand algorithmic recommendation?
# - What 'danceability' or 'valence' actually mean?
# - Whether corpus analysis is fundamentally different from streaming platform analytics?

# %% [markdown]
# ---
# ## Peer Response (10 minutes)
#
# After presentations, write:
#
# 1. One finding from another project that *changes* how you interpret your own results
# 2. One question this course has opened that you could pursue further
# 3. One thing corpus analysis *cannot* do that matters for this repertoire

# %% [markdown]
# ---
# ## Project Log — Entry 8 (Final)
#
# > *One finding from another student that changes my thinking: [X]*
# > *One question I could pursue further: [Y]*
# > *One thing corpus analysis cannot do that matters here: [Z]*
#
# *(No length requirement — write what actually stayed with you.)*

# %% [markdown]
# ---
# ## Further Resources
#
# - Corpus: https://shanahdt.github.io/mode_in_klezmer/
# - Paper: Malin & Shanahan (2025), *MTO* 31(3)
# - Mongeau & Sankoff (1990). Comparison of Musical Sequences. *Computers and the Humanities* 24(3).
# - Slobin, M. (1986). A Fresh Look at Beregovski's Folk Music Research. *Ethnomusicology* 30(2).
# - Feldman, W.Z. (2016). *Klezmer: Music, History, and Memory*. Oxford.
# - music21: https://web.mit.edu/music21/
# - librosa: https://librosa.org/
# - jupyterquiz: https://github.com/jmshea/jupyterquiz
